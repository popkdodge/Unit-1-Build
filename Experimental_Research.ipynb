# %% [markdown]
# <a href="https://colab.research.google.com/github/popkdodge/Unit-1-Build/blob/master/Experimental_Research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cf912586-9d5e-4830-80a2-6fa0d700bf93" name="files[]" multiple disabled />
#      <output id="result-cf912586-9d5e-4830-80a2-6fa0d700bf93">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
df.reset_index(drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d2b2bf0b5d7b> in <module>()
# ----> 1 df.reset_index(drop=True, inplace=True)
#
# NameError: name 'df' is not defined

# %%
df_t = df.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6fd55e8cdf26> in <module>()
# ----> 1 df_t = df.T
#
# NameError: name 'df' is not defined

# %%
df = df.set_index('Reporting Period')

# %%
df_t['Ticker'] = 'AAPL'

# %%
Ticker = df_t['Ticker']
df_t.drop(labels=['Ticker'], axis=1,inplace = True)
df_t.insert(0, 'Ticker', Ticker)
AAPL = df_t

# %%
AAPL

# %%
from google.colab import files
uploaded = files.upload()

# %%
AMZN = pd.read_csv('/content/lazyfa_export_amzn_quarterly_metrics_AMZN - lazyfa_export_amzn_quarterly_metrics_AMZN.csv')

# %%
AMZN = AMZN.set_index('Reporting Period')

# %%
MSFT = MSFT.T
MSFT['Ticker'] = 'MSFT'
Ticker = MSFT['Ticker']
MSFT.drop(labels=['Ticker'], axis=1,inplace = True)
MSFT.insert(0, 'Ticker', Ticker)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-90be5b981f2a> in <module>()
# ----> 1 MSFT = MSFT.T
#       2 MSFT['Ticker'] = 'MSFT'
#       3 Ticker = MSFT['Ticker']
#       4 MSFT.drop(labels=['Ticker'], axis=1,inplace = True)
#       5 MSFT.insert(0, 'Ticker', Ticker)
#
# NameError: name 'MSFT' is not defined

# %%
AMZN

# %%
#USE THIS AS A GUIDE
AMZN = pd.read_csv('AMZN.csv')
AMZN = AMZN.set_index('Reporting Period')
AMZN = AMZN.T
AMZN['Ticker'] = 'AMZN'
Ticker = AMZN['Ticker']
AMZN.drop(labels=['Ticker'], axis=1,inplace = True)
AMZN.insert(0, 'Ticker', Ticker)
AMZN
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-31         AMZN  ...     6.274000e+09
# 2019-12-31         AMZN  ...     8.522000e+09
# 2019-09-30         AMZN  ...     6.918000e+09
# 2019-06-30         AMZN  ...     7.112000e+09
# 2019-03-31         AMZN  ...     5.736000e+09
# 2018-12-31         AMZN  ...     6.710000e+09
# 2018-09-30         AMZN  ...     4.561000e+09
# 2018-06-30         AMZN  ...     3.680000e+09
# 2018-03-31         AMZN  ...     2.784000e+09
# 2017-12-31         AMZN  ...     2.314000e+09
#
# [10 rows x 37 columns]

# %%
WMT = pd.read_csv('WMT.csv')
WMT = WMT.set_index('Reporting Period')
WMT = WMT.T
WMT['Ticker'] = 'WMT'
Ticker = WMT['Ticker']
WMT.drop(labels=['Ticker'], axis=1,inplace = True)
WMT.insert(0, 'Ticker', Ticker)
WMT
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-01-31          WMT  ...    -1.598400e+10
# 2019-10-31          WMT  ...    -1.587200e+10
# 2019-07-31          WMT  ...    -1.891200e+10
# 2019-04-30          WMT  ...    -1.814900e+10
# 2019-01-31          WMT  ...    -1.558000e+10
# 2018-10-31          WMT  ...    -1.630500e+10
# 2018-07-31          WMT  ...    -5.313000e+09
# 2018-04-30          WMT  ...    -2.151500e+10
# 2018-01-31          WMT  ...    -1.885700e+10
# 2017-10-31          WMT  ...    -1.506700e+10
#
# [10 rows x 37 columns]

# %%
PG = pd.read_csv('PG.csv')
PG = PG.set_index('Reporting Period')
PG = PG.T
PG['Ticker'] = 'PG'
Ticker = PG['Ticker']
PG.drop(labels=['Ticker'], axis=1,inplace = True)
PG.insert(0, 'Ticker', Ticker)
PG
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-31           PG  ...    -5.756000e+09
# 2019-12-31           PG  ...    -1.124700e+10
# 2019-09-30           PG  ...    -8.328000e+09
# 2019-06-30           PG  ...    -7.538000e+09
# 2019-03-31           PG  ...    -6.058000e+09
# 2018-12-31           PG  ...    -6.816000e+09
# 2018-09-30           PG  ...    -5.874000e+09
# 2018-06-30           PG  ...    -4.917000e+09
# 2018-03-31           PG  ...    -2.751000e+09
# 2017-12-31           PG  ...    -1.893000e+09
#
# [10 rows x 37 columns]

# %%
BRK = pd.read_csv('BRK.csv')
BRK = BRK.set_index('Reporting Period')
BRK = BRK.T
BRK['Ticker'] = 'BRK'
Ticker = BRK['Ticker']
BRK.drop(labels=['Ticker'], axis=1,inplace = True)
BRK.insert(0, 'Ticker', Ticker)
BRK
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-31          BRK  ...              NaN
# 2019-12-31          BRK  ...              NaN
# 2019-09-30          BRK  ...              NaN
# 2019-06-30          BRK  ...              NaN
# 2019-03-31          BRK  ...              NaN
# 2018-12-31          BRK  ...              NaN
# 2018-09-30          BRK  ...              NaN
# 2018-06-30          BRK  ...              NaN
# 2018-03-31          BRK  ...              NaN
# 2017-12-31          BRK  ...              NaN
#
# [10 rows x 37 columns]

# %%
V = pd.read_csv('V.csv')
V = V.set_index('Reporting Period')
V = V.T
V['Ticker'] = 'V'
Ticker = V['Ticker']
V.drop(labels=['Ticker'], axis=1,inplace = True)
V.insert(0, 'Ticker', Ticker)
V
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-31            V  ...     3.965000e+09
# 2019-12-31            V  ...     4.740000e+09
# 2019-09-30            V  ...     7.555000e+09
# 2019-06-30            V  ...     7.476000e+09
# 2019-03-31            V  ...     7.110000e+09
# 2018-12-31            V  ...     6.718000e+09
# 2018-09-30            V  ...     6.911000e+09
# 2018-06-30            V  ...     7.557000e+09
# 2018-03-31            V  ...     8.985000e+09
# 2017-12-31            V  ...     8.924000e+09
#
# [10 rows x 37 columns]

# %%
MA = pd.read_csv('MA.csv')
MA = MA.set_index('Reporting Period')
MA = MA.T
MA['Ticker'] = 'MA'
Ticker = MA['Ticker']
MA.drop(labels=['Ticker'], axis=1,inplace = True)
MA.insert(0, 'Ticker', Ticker)
MA
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-31           MA  ...     8.411000e+09
# 2019-12-31           MA  ...     4.998000e+09
# 2019-09-30           MA  ...     4.133000e+09
# 2019-06-30           MA  ...     4.668000e+09
# 2019-03-31           MA  ...     4.150000e+09
# 2018-12-31           MA  ...     4.578000e+09
# 2018-09-30           MA  ...     5.355000e+09
# 2018-06-30           MA  ...     4.850000e+09
# 2018-03-31           MA  ...     5.759000e+09
# 2017-12-31           MA  ...     5.004000e+09
#
# [10 rows x 37 columns]

# %%
JNJ = pd.read_csv('JNJ.csv')
JNJ = JNJ.set_index('Reporting Period')
JNJ = JNJ.T
JNJ['Ticker'] = 'JNJ'
Ticker = JNJ['Ticker']
JNJ.drop(labels=['Ticker'], axis=1,inplace = True)
JNJ.insert(0, 'Ticker', Ticker)
JNJ
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-29          JNJ  ...     1.053700e+10
# 2019-12-29          JNJ  ...     9.310000e+09
# 2019-09-29          JNJ  ...     9.171000e+09
# 2019-06-30          JNJ  ...     1.044600e+10
# 2019-03-31          JNJ  ...     1.287600e+10
# 2018-12-30          JNJ  ...     1.480300e+10
# 2018-09-30          JNJ  ...     1.975700e+10
# 2018-07-01          JNJ  ...     1.795000e+10
# 2018-04-01          JNJ  ...     1.568700e+10
# 2017-12-31          JNJ  ...     1.255100e+10
#
# [10 rows x 37 columns]

# %%
KO = pd.read_csv('KO.csv')
KO = KO.set_index('Reporting Period')
KO = KO.T
KO['Ticker'] = 'KO'
Ticker = KO['Ticker']
KO.drop(labels=['Ticker'], axis=1,inplace = True)
KO.insert(0, 'Ticker', Ticker)
KO
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-27           KO  ...    -4.163000e+09
# 2019-12-31           KO  ...    -6.562000e+09
# 2019-09-27           KO  ...    -1.983000e+09
# 2019-06-28           KO  ...    -5.022000e+09
# 2019-03-29           KO  ...     5.970000e+08
# 2018-12-31           KO  ...    -3.852000e+09
# 2018-09-28           KO  ...     1.983000e+09
# 2018-06-29           KO  ...     4.626000e+09
# 2018-03-30           KO  ...     6.562000e+09
# 2017-12-31           KO  ...     9.351000e+09
#
# [10 rows x 37 columns]

# %%
AAPL = pd.read_csv('AAPL.csv')
AAPL = AAPL.set_index('Reporting Period')
AAPL = AAPL.T
AAPL['Ticker'] = 'AAPL'
Ticker = AAPL['Ticker']
AAPL.drop(labels=['Ticker'], axis=1,inplace = True)
AAPL.insert(0, 'Ticker', Ticker)
AAPL
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-28         AAPL  ...     4.765900e+10
# 2019-12-28         AAPL  ...     6.107000e+10
# 2019-09-28         AAPL  ...     5.710100e+10
# 2019-06-29         AAPL  ...     4.526900e+10
# 2019-03-30         AAPL  ...     2.957400e+10
# 2018-12-29         AAPL  ...     3.254500e+10
# 2018-09-29         AAPL  ...     1.541000e+10
# 2018-06-30         AAPL  ...     2.721300e+10
# 2018-03-31         AAPL  ...     4.073300e+10
# 2017-12-30         AAPL  ...     2.802200e+10
#
# [10 rows x 37 columns]

# %%
AMZN = pd.read_csv('AMZN.csv')
AMZN = AMZN.set_index('Reporting Period')
AMZN = AMZN.T
AMZN['Ticker'] = 'AMZN'
Ticker = AMZN['Ticker']
AMZN.drop(labels=['Ticker'], axis=1,inplace = True)
AMZN.insert(0, 'Ticker', Ticker)
AMZN
# Some companies was re-run to change values to TTM
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-31         AMZN  ...     6.274000e+09
# 2019-12-31         AMZN  ...     8.522000e+09
# 2019-09-30         AMZN  ...     6.918000e+09
# 2019-06-30         AMZN  ...     7.112000e+09
# 2019-03-31         AMZN  ...     5.736000e+09
# 2018-12-31         AMZN  ...     6.710000e+09
# 2018-09-30         AMZN  ...     4.561000e+09
# 2018-06-30         AMZN  ...     3.680000e+09
# 2018-03-31         AMZN  ...     2.784000e+09
# 2017-12-31         AMZN  ...     2.314000e+09
#
# [10 rows x 37 columns]

# %%
MSFT = pd.read_csv('MSFT.csv')
MSFT = MSFT.set_index('Reporting Period')
MSFT = MSFT.T
MSFT['Ticker'] = 'MSFT'
Ticker = MSFT['Ticker']
MSFT.drop(labels=['Ticker'], axis=1,inplace = True)
MSFT.insert(0, 'Ticker', Ticker)
MSFT
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-31         MSFT  ...     1.117980e+11
# 2019-12-31         MSFT  ...     1.074340e+11
# 2019-09-30         MSFT  ...     1.077780e+11
# 2019-06-30         MSFT  ...     1.061320e+11
# 2019-03-31         MSFT  ...     1.060260e+11
# 2018-12-31         MSFT  ...     1.065560e+11
# 2018-09-30         MSFT  ...     1.079180e+11
# 2018-06-30         MSFT  ...     1.111740e+11
# 2018-03-31         MSFT  ...     1.105260e+11
# 2017-12-31         MSFT  ...     1.095340e+11
#
# [10 rows x 37 columns]

# %%
HD = pd.read_csv('HD.csv')
HD = HD.set_index('Reporting Period')
HD = HD.T
HD['Ticker'] = 'HD'
Ticker = HD['Ticker']
HD.drop(labels=['Ticker'], axis=1,inplace = True)
HD.insert(0, 'Ticker', Ticker)
HD
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-02-02           HD  ...     1.435000e+09
# 2019-11-03           HD  ...     1.609000e+09
# 2019-08-04           HD  ...     1.901000e+09
# 2019-05-05           HD  ...     8.800000e+08
# 2019-02-03           HD  ...     1.813000e+09
# 2018-10-28           HD  ...     1.613000e+09
# 2018-07-29           HD  ...     2.376000e+09
# 2018-04-29           HD  ...     3.081000e+09
# 2018-01-28           HD  ...     2.739000e+09
# 2017-10-29           HD  ...     3.680000e+09
#
# [10 rows x 37 columns]

# %%
XOM = pd.read_csv('XOM.csv')
XOM = XOM.set_index('Reporting Period')
XOM = XOM.T
XOM['Ticker'] = 'XOM'
Ticker = XOM['Ticker']
XOM.drop(labels=['Ticker'], axis=1,inplace = True)
XOM.insert(0, 'Ticker', Ticker)
XOM
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-31          XOM  ...    -1.452400e+10
# 2019-12-31          XOM  ...    -1.393700e+10
# 2019-09-30          XOM  ...    -1.418700e+10
# 2019-06-30          XOM  ...    -1.854400e+10
# 2019-03-31          XOM  ...    -1.505600e+10
# 2018-12-31          XOM  ...    -9.165000e+09
# 2018-09-30          XOM  ...    -1.131300e+10
# 2018-06-30          XOM  ...    -1.189200e+10
# 2018-03-31          XOM  ...    -1.199100e+10
# 2017-12-31          XOM  ...    -1.063700e+10
#
# [10 rows x 37 columns]

# %%
INTC = pd.read_csv('INTC.csv')
INTC = INTC.set_index('Reporting Period')
INTC = INTC.T
INTC['Ticker'] = 'INTC'
Ticker = INTC['Ticker']
INTC.drop(labels=['Ticker'], axis=1,inplace = True)
INTC.insert(0, 'Ticker', Ticker)
INTC
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-28         INTC  ...     1.760600e+10
# 2019-12-28         INTC  ...     8.929000e+09
# 2019-09-28         INTC  ...     4.893000e+09
# 2019-06-29         INTC  ...     9.534000e+09
# 2019-03-30         INTC  ...     1.014900e+10
# 2018-12-29         INTC  ...     1.216100e+10
# 2018-09-29         INTC  ...     1.001600e+10
# 2018-06-30         INTC  ...     1.003200e+10
# 2018-03-31         INTC  ...     1.166900e+10
# 2017-12-30         INTC  ...     1.207900e+10
#
# [10 rows x 37 columns]

# %%
JPM = pd.read_csv('JPM.csv')
JPM = JPM.set_index('Reporting Period')
JPM = JPM.T
JPM['Ticker'] = 'JPM'
Ticker = JPM['Ticker']
JPM.drop(labels=['Ticker'], axis=1,inplace = True)
JPM.insert(0, 'Ticker', Ticker)
JPM
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-31          JPM  ...              NaN
# 2019-12-31          JPM  ...              NaN
# 2019-09-30          JPM  ...              NaN
# 2019-06-30          JPM  ...              NaN
# 2019-03-31          JPM  ...              NaN
# 2018-12-31          JPM  ...              NaN
# 2018-09-30          JPM  ...              NaN
# 2018-06-30          JPM  ...              NaN
# 2018-03-31          JPM  ...              NaN
# 2017-12-31          JPM  ...              NaN
#
# [10 rows x 37 columns]

# %%
CRM = pd.read_csv('CRM.csv')
CRM = CRM.set_index('Reporting Period')
CRM = CRM.T
CRM['Ticker'] = 'CRM'
Ticker = CRM['Ticker']
CRM.drop(labels=['Ticker'], axis=1,inplace = True)
CRM.insert(0, 'Ticker', Ticker)
CRM
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-01-31          CRM  ...     1.118000e+09
# 2019-10-31          CRM  ...     5.520000e+08
# 2019-07-31          CRM  ...    -2.920000e+08
# 2019-04-30          CRM  ...    -4.530000e+08
# 2019-01-31          CRM  ...    -5.720000e+08
# 2018-10-31          CRM  ...    -1.152000e+09
# 2018-07-31          CRM  ...    -1.667000e+09
# 2018-04-30          CRM  ...     2.256000e+09
# 2018-01-31          CRM  ...    -4.830000e+08
# 2017-10-31          CRM  ...    -1.270274e+09
#
# [10 rows x 37 columns]

# %%
BA = pd.read_csv('BA.csv')
BA = BA.set_index('Reporting Period')
BA = BA.T
BA['Ticker'] = 'BA'
Ticker = BA['Ticker']
BA.drop(labels=['Ticker'], axis=1,inplace = True)
BA.insert(0, 'Ticker', Ticker)
BA
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-31           BA  ...     1.650900e+10
# 2019-12-31           BA  ...     4.917000e+09
# 2019-09-30           BA  ...     9.810000e+09
# 2019-06-30           BA  ...     2.922000e+09
# 2019-03-31           BA  ...     5.894000e+09
# 2018-12-31           BA  ...     6.240000e+09
# 2018-09-30           BA  ...     8.269000e+09
# 2018-06-30           BA  ...     8.676000e+09
# 2018-03-31           BA  ...     1.101100e+10
# 2017-12-31           BA  ...     1.054600e+10
#
# [10 rows x 37 columns]

# %%
PFE = pd.read_csv('PFE.csv')
PFE = PFE.set_index('Reporting Period')
PFE = PFE.T
PFE['Ticker'] = 'PFE'
Ticker = PFE['Ticker']
PFE.drop(labels=['Ticker'], axis=1,inplace = True)
PFE.insert(0, 'Ticker', Ticker)
PFE
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-29          PFE  ...     8.480000e+08
# 2019-12-31          PFE  ...    -4.501000e+09
# 2019-09-29          PFE  ...    -3.515000e+09
# 2019-06-30          PFE  ...     1.504300e+10
# 2019-03-31          PFE  ...     1.586700e+10
# 2018-12-31          PFE  ...     1.806800e+10
# 2018-09-30          PFE  ...     1.257000e+10
# 2018-07-01          PFE  ...     5.147000e+09
# 2018-04-01          PFE  ...     7.470000e+09
# 2017-12-31          PFE  ...     1.071400e+10
#
# [10 rows x 37 columns]

# %%
T = pd.read_csv('T.csv')
T = T.set_index('Reporting Period')
T = T.T
T['Ticker'] = 'T'
Ticker = T['Ticker']
T.drop(labels=['Ticker'], axis=1,inplace = True)
T.insert(0, 'Ticker', Ticker)
T
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-31            T  ...    -1.700000e+10
# 2019-12-31            T  ...    -1.415000e+10
# 2019-09-30            T  ...    -1.743100e+10
# 2019-06-30            T  ...    -1.915800e+10
# 2019-03-31            T  ...    -1.818000e+10
# 2018-12-31            T  ...    -1.299300e+10
# 2018-09-30            T  ...    -1.231300e+10
# 2018-06-30            T  ...    -1.330700e+10
# 2018-03-31            T  ...     7.925000e+09
# 2017-12-31            T  ...    -2.243000e+09
#
# [10 rows x 37 columns]

# %%
IBM = pd.read_csv('IBM.csv')
IBM = IBM.set_index('Reporting Period')
IBM = IBM.T
IBM['Ticker'] = 'IBM'
Ticker = IBM['Ticker']
IBM.drop(labels=['Ticker'], axis=1,inplace = True)
IBM.insert(0, 'Ticker', Ticker)
IBM
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-31          IBM  ...    -1.742000e+09
# 2019-12-31          IBM  ...     7.190000e+08
# 2019-09-30          IBM  ...     3.055000e+09
# 2019-06-30          IBM  ...     3.516600e+10
# 2019-03-31          IBM  ...     1.383400e+10
# 2018-12-31          IBM  ...     1.091900e+10
# 2018-09-30          IBM  ...     1.143500e+10
# 2018-06-30          IBM  ...     1.135300e+10
# 2018-03-31          IBM  ...     1.338900e+10
# 2017-12-31          IBM  ...     1.237200e+10
#
# [10 rows x 37 columns]

# %%
GOOGL = pd.read_csv('GOOGL.csv')
GOOGL = GOOGL.set_index('Reporting Period')
GOOGL = GOOGL.T
GOOGL['Ticker'] = 'GOOGL'
Ticker = GOOGL['Ticker']
GOOGL.drop(labels=['Ticker'], axis=1,inplace = True)
GOOGL.insert(0, 'Ticker', Ticker)
GOOGL
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-31        GOOGL  ...     1.068290e+11
# 2019-12-31        GOOGL  ...     1.073570e+11
# 2019-09-30        GOOGL  ...     1.091340e+11
# 2019-06-30        GOOGL  ...     1.104370e+11
# 2019-03-31        GOOGL  ...     1.032970e+11
# 2018-12-31        GOOGL  ...     1.010560e+11
# 2018-09-30        GOOGL  ...     9.840100e+10
# 2018-06-30        GOOGL  ...     9.425400e+10
# 2018-03-31        GOOGL  ...     9.836700e+10
# 2017-12-31        GOOGL  ...     1.001250e+11
#
# [10 rows x 37 columns]

# %%
Pop_20 = [AAPL, AMZN, BA, BRK, CRM, GOOGL, HD, IBM, INTC, JNJ, JPM, KO, MA, MSFT, PFE, PG, T, V, WMT, XOM]
Pop_20_Index = pd.concat(Pop_20)

# %%
AAPL.shape
# Out:
# (10, 37)

# %%
list(Pop_20_Index)
# Out:
# ['Ticker',
#  'Asset Turnover',
#  'Average Assets',
#  'Book Value per Share',
#  'Current Ratio',
#  'Debt to Equity Ratio',
#  'Dividend Yield',
#  'EBITDA',
#  'EBITDA [USD]',
#  'EBITDA Margin',
#  'Earnings before Tax',
#  'Average Equity',
#  'Enterprise Value',
#  'Enterprise Value over EBIT',
#  'Enterprise Value over EBITDA',
#  'Free Cash Flow',
#  'Free Cash Flow per Share',
#  'Foreign Currency to USD Exchange Rate',
#  'Gross Margin',
#  'Invested Capital',
#  'Invested Capital Average',
#  'Market Capitalization',
#  'Profit Margin',
#  'Price to Earnings (Damodaran Method)',
#  'Price to Earnings Ratio',
#  'Price to Sales Ratio',
#  'Price to Sales (Damodaran Method)',
#  'Price to Book Value',
#  'Return on Invested Capital',
#  'Sales per Share',
#  'Payout Ratio',
#  'Return on Average Assets',
#  'Return on Average Equity',
#  'Return on Sales',
#  'Tangible Asset Value',
#  'Tangible Asset Book Value per Share',
#  'Working Capital']

# %%
Pop_20_Index['Reporting Period'] = pd.to_datetime(Pop_20_Index['Reporting Period'], 
                                        infer_datetime_format=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Reporting Period'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-ff3afd91aa43> in <module>()
# ...

# %%
Pop_20_Index
# Out:
# Reporting Period Ticker  ...  Working Capital
# 2020-03-28         AAPL  ...     4.765900e+10
# 2019-12-28         AAPL  ...     6.107000e+10
# 2019-09-28         AAPL  ...     5.710100e+10
# 2019-06-29         AAPL  ...     4.526900e+10
# 2019-03-30         AAPL  ...     2.957400e+10
# ...                 ...  ...              ...
# 2018-12-31          XOM  ...    -9.165000e+09
# 2018-09-30          XOM  ...    -1.131300e+10
# 2018-06-30          XOM  ...    -1.189200e+10
# 2018-03-31          XOM  ...    -1.199100e+10
# 2017-12-31          XOM  ...    -1.063700e+10
#
# [200 rows x 37 columns]

# %%
Pop_20_Index = Pop_20_Index.reset_index()

# %%
list(Pop_20_Index)

# %%
Pop_20_Index.columns = ['Time',
 'Ticker',
 'Asset Turnover',
 'Average Assets',
 'Book Value per Share',
 'Current Ratio',
 'Debt to Equity Ratio',
 'Dividend Yield',
 'EBITDA',
 'EBITDA [USD]',
 'EBITDA Margin',
 'Earnings before Tax',
 'Average Equity',
 'Enterprise Value',
 'Enterprise Value over EBIT',
 'Enterprise Value over EBITDA',
 'Free Cash Flow',
 'Free Cash Flow per Share',
 'Foreign Currency to USD Exchange Rate',
 'Gross Margin',
 'Invested Capital',
 'Invested Capital Average',
 'Market Capitalization',
 'Profit Margin',
 'Price to Earnings (Damodaran Method)',
 'Price to Earnings Ratio',
 'Price to Sales Ratio',
 'Price to Sales (Damodaran Method)',
 'Price to Book Value',
 'Return on Invested Capital',
 'Sales per Share',
 'Payout Ratio',
 'Return on Average Assets',
 'Return on Average Equity',
 'Return on Sales',
 'Tangible Asset Value',
 'Tangible Asset Book Value per Share',
 'Working Capital']

# %%
'''Pop_20_Index
Pop_20_Index['Time'] = pd.to_datetime(Pop_20_Index['Time'], 
                                        infer_datetime_format=True)'''

# %%
pop20_sort = Pop_20_Index.sort_values(by='Time')

# %%
pop20_sort.to_csv('pop20.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1232e2f68d51> in <module>()
# ----> 1 pop20_sort.to_csv('pop20.csv')
#
# NameError: name 'pop20_sort' is not defined

# %%
import pandas as pd

Pop_20_Index = pd.read_csv('pop20.csv')

Pop_20_Index
# Out:
#      Unnamed: 0  ... Working Capital
# 0            69  ...    3.680000e+09
# 1           189  ...   -1.506700e+10
# 2            49  ...   -1.270274e+09
# 3             9  ...    2.802200e+10
# 4            89  ...    1.207900e+10
# ..          ...  ...             ...
# 195          70  ...   -1.742000e+09
# 196          50  ...    1.068290e+11
# 197          30  ...             NaN
# 198         170  ...    3.965000e+09
# 199          10  ...    6.274000e+09
#
# [200 rows x 39 columns]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(20, 10))
sns.set(style="whitegrid")

ax = sns.lineplot(x=range(0, 200), y='Free Cash Flow', hue='Ticker' ,data=pop20_sort)
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(20, 10))
sns.set(style="whitegrid")

ax = sns.lineplot(x=range(0, 200), y='Market Capitalization', hue='Ticker' ,data=pop20_sort)
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(20, 10))
sns.set(style="whitegrid")

ax = sns.lineplot(x=range(0, 200), y='Return on Invested Capital', hue='Ticker' ,data=pop20_sort)
plt.show()

# %%
sns.relplot

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(10, 10))
sns.set(style="whitegrid")

ax = sns.relplot(x='Market Capitalization', y='Return on Invested Capital', hue='Ticker' ,data=pop20_sort)
plt.show()

# %%
condition_maga = ((pop20_sort["Ticker"] == 'MSFT')|(pop20_sort['Ticker'] == 'AMZN')|(pop20_sort['Ticker'] == 'GOOGL')|(pop20_sort['Ticker'] == 'AAPL'))

# %%
maga = pop20_sort[condition_maga]

# %%
maga.columns
# Out:
# Index(['Unnamed: 0', 'Time', 'Ticker', 'Asset Turnover', 'Average Assets',
#        'Book Value per Share', 'Current Ratio', 'Debt to Equity Ratio',
#        'Dividend Yield', 'EBITDA', 'EBITDA [USD]', 'EBITDA Margin',
#        'Earnings before Tax', 'Average Equity', 'Enterprise Value',
#        'Enterprise Value over EBIT', 'Enterprise Value over EBITDA',
#        'Free Cash Flow', 'Free Cash Flow per Share',
#        'Foreign Currency to USD Exchange Rate', 'Gross Margin',
#        'Invested Capital', 'Invested Capital Average', 'Market Capitalization',
#        'Profit Margin', 'Price to Earnings (Damodaran Method)',
#        'Price to Earnings Ratio', 'Price to Sales Ratio',
#        'Price to Sales (Damodaran Method)', 'Price to Book Value',
#        'Return on Invested Capital', 'Sales per Share', 'Payout Ratio',
#        'Return on Average Assets', 'Return on Average Equity',
#        'Return on Sales', 'Tangible Asset Value',
# ...

# %%
maga = maga.drop(['Unnamed: 0'], axis=1)

# %%
maga = maga.reset_index()

# %%
# Out:
# Series([], dtype: float64)

# %%
maga = maga.drop(['EBITDA'], axis=1)

# %%
maga.corr()
# Out:
#                                        Asset Turnover  ...  Working Capital
# Asset Turnover                               1.000000  ...        -0.849052
# Average Assets                              -0.637597  ...         0.181449
# Book Value per Share                         0.001206  ...         0.268251
# Current Ratio                               -0.657415  ...         0.875748
# Debt to Equity Ratio                         0.590382  ...        -0.720349
# Dividend Yield                              -0.583089  ...         0.235722
# EBITDA [USD]                                -0.572154  ...         0.122362
# EBITDA Margin                               -0.957795  ...         0.845036
# Earnings before Tax                         -0.666526  ...         0.235177
# Average Equity                              -0.693792  ...         0.630164
# Enterprise Value                            -0.052136  ...        -0.193275
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(20, 10))
sns.set(style="whitegrid")

ax = sns.lineplot(x=range(0,40), y='Asset Turnover', hue='Ticker' ,data=maga)
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(20, 10))
sns.set(style="whitegrid")

ax = sns.lineplot(x='Time', y='Market Capitalization', hue='Ticker' ,data=maga)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-41b8812d07f5> in <module>()
#       6 sns.set(style="whitegrid")
#       7
# ----> 8 ax = sns.lineplot(x='Time', y='Market Capitalization', hue='Ticker' ,data=maga)
#       9 plt.show()
#
# NameError: name 'maga' is not defined

# %%
import plotly.express as px
df = pop20_sort
fig = px.scatter(df, x='Asset Turnover', y='Price to Earnings Ratio', color="Ticker",
                 size='Market Capitalization', hover_data=['Return on Invested Capital'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e1cf367c-6634-4a9b-b87f-f7a93eb8d520" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e1cf367c-6634-4a9b-b87f-f7a93eb8d520")) {
#                     Plotly.newPlot(
#                         'e1cf367c-6634-4a9b-b87f-f7a93eb8d520',
# ...

# %%
import plotly.express as px
df = maga
fig = px.scatter_matrix(df,
    dimensions=['Debt to Equity Ratio', 'EBITDA [USD]','Free Cash Flow','Market Capitalization',
 'Profit Margin','Return on Invested Capital'],color='Ticker',
    width=1500, height=1500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7074039e-c553-42af-b6e9-578ffeedb2e9" class="plotly-graph-div" style="height:1500px; width:1500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7074039e-c553-42af-b6e9-578ffeedb2e9")) {
#                     Plotly.newPlot(
#                         '7074039e-c553-42af-b6e9-578ffeedb2e9',
# ...

# %%
list(maga)
# Out:
# ['Time',
#  'Ticker',
#  'Asset Turnover',
#  'Average Assets',
#  'Book Value per Share',
#  'Current Ratio',
#  'Debt to Equity Ratio',
#  'Dividend Yield',
#  'EBITDA [USD]',
#  'EBITDA Margin',
#  'Earnings before Tax',
#  'Average Equity',
#  'Enterprise Value',
#  'Enterprise Value over EBIT',
#  'Enterprise Value over EBITDA',
#  'Free Cash Flow',
#  'Free Cash Flow per Share',
#  'Foreign Currency to USD Exchange Rate',
#  'Gross Margin',
#  'Invested Capital',
#  'Invested Capital Average',
#  'Market Capitalization',
#  'Profit Margin',
#  'Price to Earnings (Damodaran Method)',
#  'Price to Earnings Ratio',
#  'Price to Sales Ratio',
#  'Price to Sales (Damodaran Method)',
#  'Price to Book Value',
#  'Return on Invested Capital',
#  'Sales per Share',
#  'Payout Ratio',
#  'Return on Average Assets',
#  'Return on Average Equity',
#  'Return on Sales',
#  'Tangible Asset Value',
#  'Tangible Asset Book Value per Share',
#  'Working Capital']

# %%
import plotly.express as px

df = pop20_sort 
fig = px.line(df, x='Time', y='Price to Earnings Ratio', color="Ticker",
              line_group='Ticker', hover_name="Ticker")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ed81edc1-fe38-4146-a6a2-f241a8f4ce09" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ed81edc1-fe38-4146-a6a2-f241a8f4ce09")) {
#                     Plotly.newPlot(
#                         'ed81edc1-fe38-4146-a6a2-f241a8f4ce09',
# ...

# %%
DAL_Quote = pd.read_csv('DAL_Quote_Fix.csv')

# %%
DAL_Quote
# Out:
#      Unnamed: 0        Date   Close/Last    Volume   Open   High      Low
# 0           252  2019-05-22        54.06   3616690  54.49  54.84  53.8900
# 1           251  2019-05-23        54.00   5279103  53.65  54.75  53.2400
# 2           250  2019-05-24        54.12   2503194  54.42  54.62  53.7100
# 3           249  2019-05-28        53.88   3454118  54.14  54.63  53.8700
# 4           248  2019-05-29        53.21   3929675  53.75  53.75  52.8100
# ..          ...         ...          ...       ...    ...    ...      ...
# 248           4  2020-05-15        19.19  46861840  18.97  19.65  18.6200
# 249           3  2020-05-18        21.86  74681700  20.91  21.94  20.5500
# 250           2  2020-05-19        21.76  70906350  22.57  22.57  21.3200
# 251           1  2020-05-20        22.72  50856960  22.34  23.10  22.1400
# 252           0  2020-05-21        23.16  46567250  22.77  23.68  22.6668
#
# [253 rows x 7 columns]

# %%
DAL_Quote = DAL_Quote.sort_values(by='Date',ascending=True)

# %%
DAL_Quote.dtypes
# Out:
# Unnamed: 0       int64
# Date            object
#  Close/Last    float64
#  Volume          int64
#  Open          float64
#  High          float64
#  Low           float64
# dtype: object

# %%
DAL_Quote[' Open'] = DAL_Quote[' Open'].str.replace('$', '')

# %%
DAL_Quote[' High'] = DAL_Quote[' High'].str.replace('$', '')

# %%
DAL_Quote[' Low'] = DAL_Quote[' Low'].str.replace('$', '')

# %%
DAL_Quote[' Close/Last'].str.replace('$', '')

# %%
DAL_Quote[' Open'] = DAL_Quote[' Open'].astype(float)

# %%
DAL_Quote[' High'] = DAL_Quote[' High'].astype(float)

# %%
DAL_Quote[' Low'] = DAL_Quote[' Low'].astype(float)

# %%
DAL_Quote[' Close/Last'] = DAL_Quote[' Close/Last'].astype(float)

# %%
DAL_Quote['Date'] = pd.to_datetime(DAL_Quote['Date'], 
                                        infer_datetime_format=True)
DAL_Quote['Ticker'] = 'DAL'
Ticker = DAL_Quote['Ticker']
DAL_Quote.drop(labels=['Ticker'], axis=1,inplace = True)
DAL_Quote.insert(0, 'Ticker', Ticker)

# %%
DAL_Quote.columns
# Out:
# Index(['Date', ' Close/Last', ' Volume', ' Open', ' High', ' Low'], dtype='object')

# %%
DAL_Quote.to_csv('DAL_Quote_Fix.csv')

# %%
import plotly.graph_objects as go

import pandas as pd
from datetime import datetime

df = DAL_Quote

fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df[' Open'],
                high=df[' High'],
                low=df[' Low'],
                close=df[' Close/Last'])])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7ef81e3c-e826-46e6-a356-c3013c5f2aa1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7ef81e3c-e826-46e6-a356-c3013c5f2aa1")) {
#                     Plotly.newPlot(
#                         '7ef81e3c-e826-46e6-a356-c3013c5f2aa1',
# ...

# %%
DAL_Qs = pd.read_csv('DAL_Quarterlies.csv')

# %%
DAL_Qs
DAL_Qs = DAL_Qs.set_index('Reporting Period')
DAL_Qs = DAL_Qs.T
DAL_Qs['Ticker'] = 'DAL'
Ticker = DAL_Qs['Ticker']
DAL_Qs.drop(labels=['Ticker'], axis=1,inplace = True)
DAL_Qs.insert(0, 'Ticker', Ticker)
DAL_Qs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-ec24a0bc6189> in <module>()
#       1 DAL_Qs
# ----> 2 DAL_Qs = DAL_Qs.set_index('Reporting Period')
#       3 DAL_Qs = DAL_Qs.T
#       4 DAL_Qs['Ticker'] = 'DAL'
#       5 Ticker = DAL_Qs['Ticker']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Reporting Period'] are in the columns"

# %%
DAL_Qs.columns = ['Time', 'Ticker', 'Asset Turnover', 'Average Assets',
       'Book Value per Share', 'Current Ratio', 'Debt to Equity Ratio',
       'Dividend Yield', 'EBITDA', 'EBITDA [USD]', 'EBITDA Margin',
       'Earnings before Tax', 'Average Equity', 'Enterprise Value',
       'Enterprise Value over EBIT', 'Enterprise Value over EBITDA',
       'Free Cash Flow', 'Free Cash Flow per Share',
       'Foreign Currency to USD Exchange Rate', 'Gross Margin',
       'Invested Capital', 'Invested Capital Average', 'Market Capitalization',
       'Profit Margin', 'Price to Earnings (Damodaran Method)',
       'Price to Earnings Ratio', 'Price to Sales Ratio',
       'Price to Sales (Damodaran Method)', 'Price to Book Value',
       'Return on Invested Capital', 'Sales per Share', 'Payout Ratio',
       'Return on Average Assets', 'Return on Average Equity',
       'Return on Sales', 'Tangible Asset Value',
       'Tangible Asset Book Value per Share', 'Working Capital']

# %%
DAL_Qs = DAL_Qs.reset_index()

# %%
DAL_Qs = DAL_Qs.drop(['Asset Turnover','Average Assets'],axis=1)

# %%
DAL_Qs['Ticker'] = 'DAL'

# %%
DAL_Qs = DAL_Qs.drop('Average Equity','Return on Sales','Asset Turnover','Average Assets','Invested Capital Average','Return on Invested Capital','Return on Average Assets', 'Return on Average Equity'],axis=1)

# %%
DAL_Qs = DAL_Qs.drop(['Average Equity','Return on Sales'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-d0a5d039189b> in <module>()
# ----> 1 DAL_Qs = DAL_Qs.drop(['Average Equity','Return on Sales'],axis=1)
#       2 DAL_Qs.to_csv('DAL_Qs_Fix.csv')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
DAL_Qs.to_csv('DAL_Qs_Fix.csv')

# %%
DAL_Qs = pd.read_csv('DAL_Qs_Fix.csv')

# %%
DAL_Qs
# Out:
#    Unnamed: 0        Time  ... Tangible Asset Book Value per Share  Working Capital
# 0           0  2020-03-31  ...                              82.747    -9.117000e+09
# 1           1  2019-12-31  ...                              76.673    -1.195500e+10
# 2           2  2019-09-30  ...                              74.772    -1.326700e+10
# 3           3  2019-06-30  ...                              73.150    -1.403000e+10
# 4           4  2019-03-31  ...                              69.568    -1.412700e+10
# 5           5  2018-12-31  ...                              66.589    -1.223800e+10
# 6           6  2018-09-30  ...                              58.400    -1.143200e+10
# 7           7  2018-06-30  ...                              58.597    -1.162800e+10
# 8           8  2018-03-31  ...                              55.793    -1.228800e+10
# 9           9  2017-12-31  ...                              54.743    -1.115500e+10
#
# [10 rows x 31 columns]

# %%
import plotly.express as px
df = DAL_Qs
fig = px.scatter_matrix(df,
    dimensions=['Book Value per Share', 'Current Ratio',
       'Debt to Equity Ratio', 'Dividend Yield', 'EBITDA', 'EBITDA [USD]',
       'EBITDA Margin', 'Earnings before Tax', 'Enterprise Value',
       'Enterprise Value over EBIT', 'Enterprise Value over EBITDA',
       'Free Cash Flow', 'Free Cash Flow per Share', 'Gross Margin',
       'Invested Capital', 'Market Capitalization', 'Profit Margin',
       'Price to Earnings (Damodaran Method)', 'Price to Earnings Ratio',
       'Price to Sales Ratio', 'Price to Sales (Damodaran Method)',
       'Price to Book Value', 'Sales per Share', 'Payout Ratio',
       'Tangible Asset Value', 'Tangible Asset Book Value per Share',
       'Working Capital', 'Time'],color='Ticker',
    width=1500, height=1500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5c8b5bf3-d8a7-4f40-8786-17448aba6ac6" class="plotly-graph-div" style="height:1500px; width:1500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5c8b5bf3-d8a7-4f40-8786-17448aba6ac6")) {
#                     Plotly.newPlot(
#                         '5c8b5bf3-d8a7-4f40-8786-17448aba6ac6',
# ...

# %%
DAL_Qs.columns
# Out:
# Index(['Unnamed: 0', 'Time', 'Ticker', 'Book Value per Share', 'Current Ratio',
#        'Debt to Equity Ratio', 'Dividend Yield', 'EBITDA', 'EBITDA [USD]',
#        'EBITDA Margin', 'Earnings before Tax', 'Enterprise Value',
#        'Enterprise Value over EBIT', 'Enterprise Value over EBITDA',
#        'Free Cash Flow', 'Free Cash Flow per Share',
#        'Foreign Currency to USD Exchange Rate', 'Gross Margin',
#        'Invested Capital', 'Market Capitalization', 'Profit Margin',
#        'Price to Earnings (Damodaran Method)', 'Price to Earnings Ratio',
#        'Price to Sales Ratio', 'Price to Sales (Damodaran Method)',
#        'Price to Book Value', 'Sales per Share', 'Payout Ratio',
#        'Tangible Asset Value', 'Tangible Asset Book Value per Share',
#        'Working Capital'],
#       dtype='object')

# %%
DAL_Q = DAL_Qs

# %%
AAL_Q  = pd.read_csv('AAL_Q.csv')
AAL_Q = AAL_Q.set_index('Reporting Period')
AAL_Q = AAL_Q.T
AAL_Q['Ticker'] = 'AAL'
Ticker = AAL_Q['Ticker']
AAL_Q.drop(labels=['Ticker'], axis=1,inplace = True)
AAL_Q.insert(0, 'Ticker', Ticker)
AAL_Q = AAL_Q.reset_index()
AAL_Q = AAL_Q.drop(['Average Equity','Return on Sales','Asset Turnover','Average Assets','Invested Capital Average',
                     'Return on Invested Capital','Return on Average Assets', 'Return on Average Equity'],axis=1)
AAL_Q.columns =['Time', 'Ticker', 'Book Value per Share', 'Current Ratio',
       'Debt to Equity Ratio', 'Dividend Yield', 'EBITDA', 'EBITDA [USD]',
       'EBITDA Margin', 'Earnings before Tax', 'Enterprise Value',
       'Enterprise Value over EBIT', 'Enterprise Value over EBITDA',
       'Free Cash Flow', 'Free Cash Flow per Share',
       'Foreign Currency to USD Exchange Rate', 'Gross Margin',
       'Invested Capital', 'Market Capitalization', 'Profit Margin',
       'Price to Earnings (Damodaran Method)', 'Price to Earnings Ratio',
       'Price to Sales Ratio', 'Price to Sales (Damodaran Method)',
       'Price to Book Value', 'Sales per Share', 'Payout Ratio',
       'Tangible Asset Value', 'Tangible Asset Book Value per Share',
       'Working Capital']

AAL_Q
# Out:
#          Time Ticker  ...  Tangible Asset Book Value per Share  Working Capital
# 0   3/31/2020    AAL  ...                              123.058    -1.203800e+10
# 1  12/31/2019    AAL  ...                              122.860    -1.010500e+10
# 2   9/30/2019    AAL  ...                              123.496    -9.988000e+09
# 3   6/30/2019    AAL  ...                              125.375    -1.027300e+10
# 4   3/31/2019    AAL  ...                              121.546    -1.119500e+10
# 5  12/31/2018    AAL  ...                              118.007    -9.459000e+09
# 6   9/30/2018    AAL  ...                              100.752    -6.850000e+09
# 7   6/30/2018    AAL  ...                               99.057    -7.493000e+09
# 8   3/31/2018    AAL  ...                               99.328    -7.335000e+09
# 9  12/31/2017    AAL  ...                               97.160    -6.212000e+09
#
# [10 rows x 30 columns]

# %%
LUV_Q  = pd.read_csv('LUV_Q.csv')
LUV_Q = LUV_Q.set_index('Reporting Period')
LUV_Q = LUV_Q.T
LUV_Q['Ticker'] = 'LUV'
Ticker = LUV_Q['Ticker']
LUV_Q.drop(labels=['Ticker'], axis=1,inplace = True)
LUV_Q.insert(0, 'Ticker', Ticker)
LUV_Q = LUV_Q.reset_index()
LUV_Q = LUV_Q.drop(['Average Equity','Return on Sales','Asset Turnover','Average Assets','Invested Capital Average',
                     'Return on Invested Capital','Return on Average Assets', 'Return on Average Equity'],axis=1)
LUV_Q.columns =['Time', 'Ticker', 'Book Value per Share', 'Current Ratio',
       'Debt to Equity Ratio', 'Dividend Yield', 'EBITDA', 'EBITDA [USD]',
       'EBITDA Margin', 'Earnings before Tax', 'Enterprise Value',
       'Enterprise Value over EBIT', 'Enterprise Value over EBITDA',
       'Free Cash Flow', 'Free Cash Flow per Share',
       'Foreign Currency to USD Exchange Rate', 'Gross Margin',
       'Invested Capital', 'Market Capitalization', 'Profit Margin',
       'Price to Earnings (Damodaran Method)', 'Price to Earnings Ratio',
       'Price to Sales Ratio', 'Price to Sales (Damodaran Method)',
       'Price to Book Value', 'Sales per Share', 'Payout Ratio',
       'Tangible Asset Value', 'Tangible Asset Book Value per Share',
       'Working Capital']
LUV_Q
# Out:
#          Time Ticker  ...  Tangible Asset Book Value per Share  Working Capital
# 0   3/31/2020    LUV  ...                               50.320    -3.213000e+09
# 1  12/31/2019    LUV  ...                               47.361    -2.978000e+09
# 2   9/30/2019    LUV  ...                               47.837    -2.979000e+09
# 3   6/30/2019    LUV  ...                               46.871    -3.057000e+09
# 4   3/31/2019    LUV  ...                               46.260    -3.240000e+09
# 5  12/31/2018    LUV  ...                               45.292    -2.877000e+09
# 6   9/30/2018    LUV  ...                               45.540    -2.242000e+09
# 7   6/30/2018    LUV  ...                               44.109    -2.308000e+09
# 8   3/31/2018    LUV  ...                               41.794    -2.361000e+09
# 9  12/31/2017    LUV  ...                               40.985    -2.048000e+09
#
# [10 rows x 30 columns]

# %%
UAL_Q  = pd.read_csv('UAL_Q.csv')
UAL_Q = UAL_Q.set_index('Reporting Period')
UAL_Q = UAL_Q.T
UAL_Q['Ticker'] = 'UAL_Q'
Ticker = UAL_Q['Ticker']
UAL_Q.drop(labels=['Ticker'], axis=1,inplace = True)
UAL_Q.insert(0, 'Ticker', Ticker)
UAL_Q = UAL_Q.reset_index()
UAL_Q = UAL_Q.drop(['Average Equity','Return on Sales','Asset Turnover','Average Assets','Invested Capital Average',
                     'Return on Invested Capital','Return on Average Assets', 'Return on Average Equity'],axis=1)
UAL_Q.columns =['Time', 'Ticker', 'Book Value per Share', 'Current Ratio',
       'Debt to Equity Ratio', 'Dividend Yield', 'EBITDA', 'EBITDA [USD]',
       'EBITDA Margin', 'Earnings before Tax', 'Enterprise Value',
       'Enterprise Value over EBIT', 'Enterprise Value over EBITDA',
       'Free Cash Flow', 'Free Cash Flow per Share',
       'Foreign Currency to USD Exchange Rate', 'Gross Margin',
       'Invested Capital', 'Market Capitalization', 'Profit Margin',
       'Price to Earnings (Damodaran Method)', 'Price to Earnings Ratio',
       'Price to Sales Ratio', 'Price to Sales (Damodaran Method)',
       'Price to Book Value', 'Sales per Share', 'Payout Ratio',
       'Tangible Asset Value', 'Tangible Asset Book Value per Share',
       'Working Capital']
UAL_Q
# Out:
#          Time Ticker  ...  Tangible Asset Book Value per Share  Working Capital
# 0   3/31/2020  UAL_Q  ...                              183.855    -8.182000e+09
# 1  12/31/2019  UAL_Q  ...                              178.147    -6.744000e+09
# 2   9/30/2019  UAL_Q  ...                              173.446    -7.158000e+09
# 3   6/30/2019  UAL_Q  ...                              169.111    -7.168000e+09
# 4   3/31/2019  UAL_Q  ...                              161.108    -7.727000e+09
# 5  12/31/2018  UAL_Q  ...                              151.734    -6.745000e+09
# 6   9/30/2018  UAL_Q  ...                              135.479    -5.013000e+09
# 7   6/30/2018  UAL_Q  ...                              132.613    -5.211000e+09
# 8   3/31/2018  UAL_Q  ...                              126.357    -5.896000e+09
# 9  12/31/2017  UAL_Q  ...                              115.726    -5.630000e+09
#
# [10 rows x 30 columns]

# %%
UAL_Q.to_csv('UAL_Q_Fix.csv')
AAL_Q.to_csv('AAL_Q_Fix.csv')
LUV_Q.to_csv('LUV_Q_Fix.csv')

# %%
AAL_Quote = pd.read_csv('AAL_Quote.csv')
AAL_Quote[' Open'] = AAL_Quote[' Open'].str.replace('$', '')
AAL_Quote[' High'] = AAL_Quote[' High'].str.replace('$', '')
AAL_Quote[' Low'] = AAL_Quote[' Low'].str.replace('$', '')
AAL_Quote[' Close/Last'] = AAL_Quote[' Close/Last'].str.replace('$', '')
AAL_Quote[' Open'] = AAL_Quote[' Open'].astype(float)
AAL_Quote[' High'] = AAL_Quote[' High'].astype(float)
AAL_Quote[' Low'] = AAL_Quote[' Low'].astype(float)
AAL_Quote[' Close/Last'] = AAL_Quote[' Close/Last'].astype(float)
AAL_Quote['Date'] = pd.to_datetime(AAL_Quote['Date'], 
                                        infer_datetime_format=True)
AAL_Quote['Ticker'] = 'AAL'
Ticker = AAL_Quote['Ticker']
AAL_Quote.drop(labels=['Ticker'], axis=1,inplace = True)
AAL_Quote.insert(0, 'Ticker', Ticker)
AAL_Quote
# Out:
#     Ticker       Date   Close/Last    Volume   Open    High     Low
# 0      AAL 2020-05-22         9.70  37596760  10.02  10.120   9.630
# 1      AAL 2020-05-21         9.89  45785720   9.87  10.150   9.830
# 2      AAL 2020-05-20         9.87  44006730   9.91  10.140   9.770
# 3      AAL 2020-05-19         9.64  62242480  10.14  10.190   9.590
# 4      AAL 2020-05-18         9.87  76624410   9.62   9.940   9.360
# ..     ...        ...          ...       ...    ...     ...     ...
# 247    AAL 2019-05-31        27.23   7441190  27.80  27.920  27.105
# 248    AAL 2019-05-30        28.17   4734058  28.50  28.745  27.990
# 249    AAL 2019-05-29        28.41   6248119  28.51  28.550  27.920
# 250    AAL 2019-05-28        28.73   8362841  29.26  29.320  28.500
# 251    AAL 2019-05-24        29.17   5764067  29.69  29.940  28.980
#
# [252 rows x 7 columns]

# %%
LUV_Quote = pd.read_csv('LUV_Quote.csv')
LUV_Quote[' Open'] = LUV_Quote[' Open'].str.replace('$', '')
LUV_Quote[' High'] = LUV_Quote[' High'].str.replace('$', '')
LUV_Quote[' Low'] = LUV_Quote[' Low'].str.replace('$', '')
LUV_Quote[' Close/Last'] = LUV_Quote[' Close/Last'].str.replace('$', '')
LUV_Quote[' Open'] = LUV_Quote[' Open'].astype(float)
LUV_Quote[' High'] = LUV_Quote[' High'].astype(float)
LUV_Quote[' Low'] = LUV_Quote[' Low'].astype(float)
LUV_Quote[' Close/Last'] = LUV_Quote[' Close/Last'].astype(float)
LUV_Quote['Date'] = pd.to_datetime(LUV_Quote['Date'], 
                                        infer_datetime_format=True)
LUV_Quote['Ticker'] = 'LUV'
Ticker = LUV_Quote['Ticker']
LUV_Quote.drop(labels=['Ticker'], axis=1,inplace = True)
LUV_Quote.insert(0, 'Ticker', Ticker)
LUV_Quote
# Out:
#     Ticker       Date   Close/Last    Volume   Open   High      Low
# 0      LUV 2020-05-22        28.87  17558230  29.76  29.98  28.3100
# 1      LUV 2020-05-21        29.60  22166520  29.31  30.12  29.0200
# 2      LUV 2020-05-20        29.15  27248980  28.47  29.33  28.1724
# 3      LUV 2020-05-19        27.69  35768210  28.50  28.85  26.9301
# 4      LUV 2020-05-18        27.09  27200460  25.75  27.24  25.5500
# ..     ...        ...          ...       ...    ...    ...      ...
# 247    LUV 2019-05-31        47.60   5193949  48.91  49.01  47.4410
# 248    LUV 2019-05-30        49.39   2792344  49.57  49.89  49.0600
# 249    LUV 2019-05-29        49.56   3703345  50.15  50.15  49.1050
# 250    LUV 2019-05-28        50.03   3446591  50.73  50.93  49.9850
# 251    LUV 2019-05-24        51.15   2311899  51.11  51.56  50.8800
#
# [252 rows x 7 columns]

# %%
UAL_Quote = pd.read_csv('UAL_Quote.csv')
UAL_Quote[' Open'] = UAL_Quote[' Open'].str.replace('$', '')
UAL_Quote[' High'] = UAL_Quote[' High'].str.replace('$', '')
UAL_Quote[' Low'] = UAL_Quote[' Low'].str.replace('$', '')
UAL_Quote[' Close/Last'] = UAL_Quote[' Close/Last'].str.replace('$', '')
UAL_Quote[' Open'] = UAL_Quote[' Open'].astype(float)
UAL_Quote[' High'] = UAL_Quote[' High'].astype(float)
UAL_Quote[' Low'] = UAL_Quote[' Low'].astype(float)
UAL_Quote[' Close/Last'] = UAL_Quote[' Close/Last'].astype(float)
UAL_Quote['Date'] = pd.to_datetime(UAL_Quote['Date'], 
                                        infer_datetime_format=True)
UAL_Quote['Ticker'] = 'UAL'
Ticker = UAL_Quote['Ticker']
UAL_Quote.drop(labels=['Ticker'], axis=1,inplace = True)
UAL_Quote.insert(0, 'Ticker', Ticker)
UAL_Quote
# Out:
#     Ticker       Date   Close/Last    Volume   Open     High    Low
# 0      UAL 2020-05-22        25.40  45062050  26.38  26.5800  24.67
# 1      UAL 2020-05-21        25.84  53737290  25.09  26.5800  25.00
# 2      UAL 2020-05-20        24.91  56271960  24.38  25.3900  24.30
# 3      UAL 2020-05-19        23.68  81387950  25.62  25.6700  23.33
# 4      UAL 2020-05-18        24.13  72914840  21.79  24.2600  21.46
# ..     ...        ...          ...       ...    ...      ...    ...
# 247    UAL 2019-05-31        77.65   3554131  78.52  79.5200  77.40
# 248    UAL 2019-05-30        79.47   1528867  79.29  80.4000  79.04
# 249    UAL 2019-05-29        79.25   3133154  79.50  79.5301  78.10
# 250    UAL 2019-05-28        79.81   2242085  80.50  80.7900  79.66
# 251    UAL 2019-05-24        80.79   2266313  81.25  81.7500  80.47
#
# [252 rows x 7 columns]

# %%
UAL_Quote.to_csv('UAL_Quote_Fix.csv')
AAL_Quote.to_csv('AAL_Quote_Fix.csv')
LUV_Quote.to_csv('LUV_Quote_Fix.csv')

# %%
import plotly.graph_objects as go

import pandas as pd
from datetime import datetime

df = AAL_Quote

fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df[' Open'],
                high=df[' High'],
                low=df[' Low'],
                close=df[' Close/Last'])])

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-24a7bfc3b7a6> in <module>()
#       4 from datetime import datetime
#       5
# ----> 6 df = AAL_Quote
#       7
#       8 fig = go.Figure(data=[go.Candlestick(x=df['Date'],
#
# NameError: name 'AAL_Quote' is not defined

# %%
EXP_CONCAT = [LUV_Quote, DAL_Quote, AAL_Quote, UAL_Quote]
Airlines = pd.concat(EXP_CONCAT)

# %%
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/popkdodge/Unit-1-Build/master/Data_set_post_clean_csv/Airlines.csv')
fig = px.line(df, x='Date', y=' High', title='Stock Prices of Delta and its competitors',color="Ticker")
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="03898ba7-65c3-4083-a5e2-eefac265bbe9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("03898ba7-65c3-4083-a5e2-eefac265bbe9")) {
#                     Plotly.newPlot(
#                         '03898ba7-65c3-4083-a5e2-eefac265bbe9',
# ...

# %%
# !pip install chart_studio
# Out:
# ...
#      |████████████████████████████████| 71kB 3.1MB/s
# ...

# %%
import chart_studio
import chart_studio.plotly as py
import chart_studio.tools as tls

# %%
username = 'popkdodge'
api_key = 'VDGE4UcnAAnQIr2ShZCM'

# %%
chart_studio.tools.set_credentials_file(username=username, api_key=api_key)

# %%
py.plot(fig, filename = 'Stock Prices of Delta and its competitors', auto_open=True)
# Out:
# 'https://plotly.com/~popkdodge/1/'

# %%
Airlines
# Out:
#     Ticker       Date   Close/Last  ...     High      Low  Unnamed: 0
# 0      LUV 2020-05-22        28.87  ...  29.9800  28.3100         NaN
# 1      LUV 2020-05-21        29.60  ...  30.1200  29.0200         NaN
# 2      LUV 2020-05-20        29.15  ...  29.3300  28.1724         NaN
# 3      LUV 2020-05-19        27.69  ...  28.8500  26.9301         NaN
# 4      LUV 2020-05-18        27.09  ...  27.2400  25.5500         NaN
# ..     ...        ...          ...  ...      ...      ...         ...
# 247    UAL 2019-05-31        77.65  ...  79.5200  77.4000         NaN
# 248    UAL 2019-05-30        79.47  ...  80.4000  79.0400         NaN
# 249    UAL 2019-05-29        79.25  ...  79.5301  78.1000         NaN
# 250    UAL 2019-05-28        79.81  ...  80.7900  79.6600         NaN
# 251    UAL 2019-05-24        80.79  ...  81.7500  80.4700         NaN
#
# [1009 rows x 8 columns]

# %%
DAL_LUV.columns
# Out:
# Index(['Ticker', 'Date', ' Close/Last', ' Volume', ' Open', ' High', ' Low',
#        'Unnamed: 0'],
#       dtype='object')

# %%
DAL_Quote
# Out:
#     Ticker  Unnamed: 0       Date   Close/Last    Volume   Open   High      Low
# 0      DAL         252 2019-05-22        54.06   3616690  54.49  54.84  53.8900
# 1      DAL         251 2019-05-23        54.00   5279103  53.65  54.75  53.2400
# 2      DAL         250 2019-05-24        54.12   2503194  54.42  54.62  53.7100
# 3      DAL         249 2019-05-28        53.88   3454118  54.14  54.63  53.8700
# 4      DAL         248 2019-05-29        53.21   3929675  53.75  53.75  52.8100
# ..     ...         ...        ...          ...       ...    ...    ...      ...
# 248    DAL           4 2020-05-15        19.19  46861840  18.97  19.65  18.6200
# 249    DAL           3 2020-05-18        21.86  74681700  20.91  21.94  20.5500
# 250    DAL           2 2020-05-19        21.76  70906350  22.57  22.57  21.3200
# 251    DAL           1 2020-05-20        22.72  50856960  22.34  23.10  22.1400
# 252    DAL           0 2020-05-21        23.16  46567250  22.77  23.68  22.6668
#
# ...

# %%
DAL_LUV['Time'] = pd.to_datetime(DAL_LUV['Time'],infer_datetime_format=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cc99fae4761f> in <module>()
# ----> 1 DAL_LUV['Time'] = pd.to_datetime(DAL_LUV['Time'],infer_datetime_format=True)
#
# NameError: name 'pd' is not defined

# %%
Airlines.to_csv('Airlines.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Airlines = pd.read_csv('Airlines.csv')
Airlines
# Out:
#       Unnamed: 0 Ticker        Date  ...     High      Low  Unnamed: 0.1
# 0              0    LUV  2020-05-22  ...  29.9800  28.3100           NaN
# 1              1    LUV  2020-05-21  ...  30.1200  29.0200           NaN
# 2              2    LUV  2020-05-20  ...  29.3300  28.1724           NaN
# 3              3    LUV  2020-05-19  ...  28.8500  26.9301           NaN
# 4              4    LUV  2020-05-18  ...  27.2400  25.5500           NaN
# ...          ...    ...         ...  ...      ...      ...           ...
# 1004         247    UAL  2019-05-31  ...  79.5200  77.4000           NaN
# 1005         248    UAL  2019-05-30  ...  80.4000  79.0400           NaN
# 1006         249    UAL  2019-05-29  ...  79.5301  78.1000           NaN
# 1007         250    UAL  2019-05-28  ...  80.7900  79.6600           NaN
# 1008         251    UAL  2019-05-24  ...  81.7500  80.4700           NaN
#
# [1009 rows x 9 columns]

# %%
AAL_Q = pd.read_csv('https://raw.githubusercontent.com/popkdodge/Unit-1-Build/master/Data_set_post_clean_csv/AAL_Q_Fix.csv')

# %%
AAL_Q
# Out:
#    Unnamed: 0        Time  ... Tangible Asset Book Value per Share  Working Capital
# 0           0   3/31/2020  ...                             123.058    -1.203800e+10
# 1           1  12/31/2019  ...                             122.860    -1.010500e+10
# 2           2   9/30/2019  ...                             123.496    -9.988000e+09
# 3           3   6/30/2019  ...                             125.375    -1.027300e+10
# 4           4   3/31/2019  ...                             121.546    -1.119500e+10
# 5           5  12/31/2018  ...                             118.007    -9.459000e+09
# 6           6   9/30/2018  ...                             100.752    -6.850000e+09
# 7           7   6/30/2018  ...                              99.057    -7.493000e+09
# 8           8   3/31/2018  ...                              99.328    -7.335000e+09
# 9           9  12/31/2017  ...                              97.160    -6.212000e+09
#
# [10 rows x 31 columns]

# %%
DAL_Q = pd.read_csv('https://raw.githubusercontent.com/popkdodge/Unit-1-Build/master/Data_set_post_clean_csv/DAL_Q_Fix.csv')
DAL_Q
# Out:
#    Unnamed: 0        Time  ... Tangible Asset Book Value per Share  Working Capital
# 0           0  2020-03-31  ...                              82.747    -9.117000e+09
# 1           1  2019-12-31  ...                              76.673    -1.195500e+10
# 2           2  2019-09-30  ...                              74.772    -1.326700e+10
# 3           3  2019-06-30  ...                              73.150    -1.403000e+10
# 4           4  2019-03-31  ...                              69.568    -1.412700e+10
# 5           5  2018-12-31  ...                              66.589    -1.223800e+10
# 6           6  2018-09-30  ...                              58.400    -1.143200e+10
# 7           7  2018-06-30  ...                              58.597    -1.162800e+10
# 8           8  2018-03-31  ...                              55.793    -1.228800e+10
# 9           9  2017-12-31  ...                              54.743    -1.115500e+10
#
# [10 rows x 31 columns]

# %%
LUV_Q = pd.read_csv('https://raw.githubusercontent.com/popkdodge/Unit-1-Build/master/Data_set_post_clean_csv/LUV_Q_Fix.csv')
LUV_Q
# Out:
#    Unnamed: 0        Time  ... Tangible Asset Book Value per Share  Working Capital
# 0           0   3/31/2020  ...                              50.320    -3.213000e+09
# 1           1  12/31/2019  ...                              47.361    -2.978000e+09
# 2           2   9/30/2019  ...                              47.837    -2.979000e+09
# 3           3   6/30/2019  ...                              46.871    -3.057000e+09
# 4           4   3/31/2019  ...                              46.260    -3.240000e+09
# 5           5  12/31/2018  ...                              45.292    -2.877000e+09
# 6           6   9/30/2018  ...                              45.540    -2.242000e+09
# 7           7   6/30/2018  ...                              44.109    -2.308000e+09
# 8           8   3/31/2018  ...                              41.794    -2.361000e+09
# 9           9  12/31/2017  ...                              40.985    -2.048000e+09
#
# [10 rows x 31 columns]

# %%
UAL_Q = pd.read_csv('https://raw.githubusercontent.com/popkdodge/Unit-1-Build/master/Data_set_post_clean_csv/UAL_Q_Fix.csv')

# %%
UAL_Q['Ticker'] = 'UAL'

# %%
MarketShare = {'Airlines': ['Delta', 'American', 'Southwest', 'United', 'Alaska', 'JetBlue', 'Sprit', 'Frontier', 'Skywest', 'Hawaiian', 'Other' ], 
               'Marketshare %': ['17.6','17.5','16.7','14.8','6.4','5.5','4.3','3.6','2.9','1.6','9.6']}
MarketShareP = pd.DataFrame(data=MarketShare)
MarketShareP.to_csv('MarketShare.csv')

# %%
EXP_CONCAT3 = [LUV_Q, DAL_Q, AAL_Q, UAL_Q]
AirlinesQ = pd.concat(EXP_CONCAT3)

# %%
AirlinesQ['Time'] = pd.to_datetime(AirlinesQ['Time'], 
                                        infer_datetime_format=True)

# %%
MarketShareP
# Out:
#      Airlines Marketshare %
# 0       Delta          17.6
# 1    American          17.5
# 2   Southwest          16.7
# 3      United          14.8
# 4      Alaska           6.4
# 5     JetBlue           5.5
# 6       Sprit           4.3
# 7    Frontier           3.6
# 8     Skywest           2.9
# 9    Hawaiian           1.6
# 10      Other           9.6

# %%
import pandas as pd
import plotly.graph_objects as go
import matplotlib.pyplot as plt

MarketShare = {'Airlines': ['Delta', 'American', 'Southwest', 'United', 'Alaska', 'JetBlue', 'Spirit', 'Frontier', 'Skywest', 'Hawaiian', 'Other' ], 
               'Marketshare %': ['17.6','17.5','16.7','14.8','6.4','5.5','4.3','3.6','2.9','1.6','9.6']}
MarketShareP = pd.DataFrame(data=MarketShare)
labels = MarketShareP['Airlines']
values = MarketShareP['Marketshare %']
fig = go.Figure(data=[go.Pie(labels=labels, values=values, textinfo='label+percent'
                            )])
fig.update_layout(
title={
        'text': "Marketshare of US airlines companies",
        'y':0.9,
        'x':0.48,
        'xanchor': 'center',
        'yanchor': 'top',
        'font': dict(
        family="Courier New, monospace",
        size=23,
        color="#212121")},
annotations=[
             dict(
            x=.47,
            y=-0.21,
            showarrow=False,
            text="Source: transtats.bts.gov - United States Department of Transportation",
            xref="paper",
            yref="paper"
        )
]
        )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="78528f4f-a6c5-4155-a1f1-bf674e5fb190" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("78528f4f-a6c5-4155-a1f1-bf674e5fb190")) {
#                     Plotly.newPlot(
#                         '78528f4f-a6c5-4155-a1f1-bf674e5fb190',
# ...

# %%
py.plot(fig, filename = 'Marketshare of US airlines companies', auto_open=True)
# Out:
# 'https://plotly.com/~popkdodge/8/'

# %%
AirlinesQ.to_csv('AirlinesQ.csv')

# %%
AirlinesQ
# Out:
#    Unnamed: 0       Time  ... Tangible Asset Book Value per Share  Working Capital
# 0           0 2020-03-31  ...                              50.320    -3.213000e+09
# 1           1 2019-12-31  ...                              47.361    -2.978000e+09
# 2           2 2019-09-30  ...                              47.837    -2.979000e+09
# 3           3 2019-06-30  ...                              46.871    -3.057000e+09
# 4           4 2019-03-31  ...                              46.260    -3.240000e+09
# 5           5 2018-12-31  ...                              45.292    -2.877000e+09
# 6           6 2018-09-30  ...                              45.540    -2.242000e+09
# 7           7 2018-06-30  ...                              44.109    -2.308000e+09
# 8           8 2018-03-31  ...                              41.794    -2.361000e+09
# 9           9 2017-12-31  ...                              40.985    -2.048000e+09
# ...

# %%
AirlinesQ.columns
# Out:
# Index(['Unnamed: 0', 'Time', 'Ticker', 'Book Value per Share', 'Current Ratio',
#        'Debt to Equity Ratio', 'Dividend Yield', 'EBITDA', 'EBITDA [USD]',
#        'EBITDA Margin', 'Earnings before Tax', 'Enterprise Value',
#        'Enterprise Value over EBIT', 'Enterprise Value over EBITDA',
#        'Free Cash Flow', 'Free Cash Flow per Share',
#        'Foreign Currency to USD Exchange Rate', 'Gross Margin',
#        'Invested Capital', 'Market Capitalization', 'Profit Margin',
#        'Price to Earnings (Damodaran Method)', 'Price to Earnings Ratio',
#        'Price to Sales Ratio', 'Price to Sales (Damodaran Method)',
#        'Price to Book Value', 'Sales per Share', 'Payout Ratio',
#        'Tangible Asset Value', 'Tangible Asset Book Value per Share',
#        'Working Capital'],
#       dtype='object')

# %%
DAL_Q
# Out:
#    Unnamed: 0        Time  ... Tangible Asset Book Value per Share  Working Capital
# 0           0  2020-03-31  ...                              82.747    -9.117000e+09
# 1           1  2019-12-31  ...                              76.673    -1.195500e+10
# 2           2  2019-09-30  ...                              74.772    -1.326700e+10
# 3           3  2019-06-30  ...                              73.150    -1.403000e+10
# 4           4  2019-03-31  ...                              69.568    -1.412700e+10
# 5           5  2018-12-31  ...                              66.589    -1.223800e+10
# 6           6  2018-09-30  ...                              58.400    -1.143200e+10
# 7           7  2018-06-30  ...                              58.597    -1.162800e+10
# 8           8  2018-03-31  ...                              55.793    -1.228800e+10
# 9           9  2017-12-31  ...                              54.743    -1.115500e+10
#
# [10 rows x 31 columns]

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=DAL_Q['Gross Margin'],
                name='DAL',marker_color='rgb(0,50,104)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=LUV_Q['Gross Margin'],
                name='LUV',marker_color='rgb(242,177,18)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=AAL_Q['Gross Margin'],
                name='AAL',marker_color='rgb(179,192,199)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=UAL_Q['Gross Margin'],
                name='UAL',marker_color='rgb(2,180,232)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=DAL_Q['Gross Margin'],
                    mode='lines+markers',
                    name='DAL',marker_color='rgb(0,50,104)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=LUV_Q['Gross Margin'],
                    mode='lines+markers',
                    name='LUV',marker_color='rgb(242,177,18)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=AAL_Q['Gross Margin'],
                    mode='lines+markers',
                    name='AAL',marker_color='rgb(179,192,199)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=UAL_Q['Gross Margin'],
                    mode='lines+markers',
                    name='UAL',marker_color='rgb(2,180,232)'))





fig.update_layout(
    title={
        'text': "Gross Margin of DAL and its Competitors",
        'font': dict(
        family="Courier New, monospace",
        size=29,
        color="#212121")}
        
    ,xaxis_title='Quarterlies'
    ,yaxis_title=''
        )



fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a494b738-545b-40e7-a37a-a732368b254a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a494b738-545b-40e7-a37a-a732368b254a")) {
#                     Plotly.newPlot(
#                         'a494b738-545b-40e7-a37a-a732368b254a',
# ...

# %%
py.plot(fig, filename = 'Gross Margin of DAL and its competitors', auto_open=True)
# Out:
# 'https://plotly.com/~popkdodge/11/'

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=DAL_Q['Profit Margin'],
                name='DAL',marker_color='rgb(0,50,104)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=LUV_Q['Profit Margin'],
                name='LUV',marker_color='rgb(242,177,18)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=AAL_Q['Profit Margin'],
                name='AAL',marker_color='rgb(179,192,199)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=UAL_Q['Profit Margin'],
                name='UAL',marker_color='rgb(2,180,232)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=DAL_Q['Profit Margin'],
                    mode='lines+markers',
                    name='DAL',marker_color='rgb(0,50,104)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=LUV_Q['Profit Margin'],
                    mode='lines+markers',
                    name='LUV',marker_color='rgb(242,177,18)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=AAL_Q['Profit Margin'],
                    mode='lines+markers',
                    name='AAL',marker_color='rgb(179,192,199)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=UAL_Q['Profit Margin'],
                    mode='lines+markers',
                    name='UAL',marker_color='rgb(2,180,232)'))


fig.update_layout(
    title={
        'text': "Profit Margin of DAL and its Competitors",
        'font': dict(
        family="Courier New, monospace",
        size=29,
        color="#212121")}

            
    ,xaxis_title='Quarterlies'
    ,yaxis_title=''
        )





fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="172698a8-6c4b-4038-9a84-d5fb0fe8a53a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("172698a8-6c4b-4038-9a84-d5fb0fe8a53a")) {
#                     Plotly.newPlot(
#                         '172698a8-6c4b-4038-9a84-d5fb0fe8a53a',
# ...

# %%
py.plot(fig, filename = 'Profit Margin of DAL and its competitors', auto_open=True)
# Out:
# 'https://plotly.com/~popkdodge/14/'

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=DAL_Q['Market Capitalization'],
                name='DAL',marker_color='rgb(0,50,104)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=LUV_Q['Market Capitalization'],
                name='LUV',marker_color='rgb(242,177,18)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=AAL_Q['Market Capitalization'],
                name='AAL',marker_color='rgb(179,192,199)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=UAL_Q['Market Capitalization'],
                name='UAL',marker_color='rgb(2,180,232)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=DAL_Q['Market Capitalization'],
                    mode='lines+markers',
                    name='DAL',marker_color='rgb(0,50,104)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=LUV_Q['Market Capitalization'],
                    mode='lines+markers',
                    name='LUV',marker_color='rgb(242,177,18)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=AAL_Q['Market Capitalization'],
                    mode='lines+markers',
                    name='AAL',marker_color='rgb(179,192,199)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=UAL_Q['Market Capitalization'],
                    mode='lines+markers',
                    name='UAL',marker_color='rgb(2,180,232)'))



fig.update_layout(
    title={
        'text': "Market Capitalization of DAL and its Competitors",
        'font': dict(
        family="Courier New, monospace",
        size=29,
        color="#212121")}

            
    ,xaxis_title='Quarterlies'
    ,yaxis_title='Dollars($)'
        )


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="907bb69b-ce96-4f01-9949-94b7983ee5e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("907bb69b-ce96-4f01-9949-94b7983ee5e9")) {
#                     Plotly.newPlot(
#                         '907bb69b-ce96-4f01-9949-94b7983ee5e9',
# ...

# %%
py.plot(fig, filename = 'MarketCap of DAL and its competitors', auto_open=True)
# Out:
# 'https://plotly.com/~popkdodge/18/'

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=DAL_Q['Price to Earnings Ratio'],
                name='DAL',marker_color='rgb(0,50,104)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=LUV_Q['Price to Earnings Ratio'],
                name='LUV',marker_color='rgb(242,177,18)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=AAL_Q['Price to Earnings Ratio'],
                name='AAL',marker_color='rgb(179,192,199)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=UAL_Q['Price to Earnings Ratio'],
                name='UAL',marker_color='rgb(2,180,232)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=DAL_Q['Price to Earnings Ratio'],
                    mode='lines+markers',
                    name='DAL',marker_color='rgb(0,50,104)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=LUV_Q['Price to Earnings Ratio'],
                    mode='lines+markers',
                    name='LUV',marker_color='rgb(242,177,18)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=AAL_Q['Price to Earnings Ratio'],
                    mode='lines+markers',
                    name='AAL',marker_color='rgb(179,192,199)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=UAL_Q['Price to Earnings Ratio'],
                    mode='lines+markers',
                    name='UAL',marker_color='rgb(2,180,232)'))





fig.update_layout(
    title={
        'text': "P/E Ratio of DAL and its Competitors",
        'font': dict(
        family="Courier New, monospace",
        size=29,
        color="#212121")}

            
    ,xaxis_title='Quarterlies'
    ,yaxis_title=''
        )


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1bda9e93-5595-4ed8-86d7-5a5d9160b257" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1bda9e93-5595-4ed8-86d7-5a5d9160b257")) {
#                     Plotly.newPlot(
#                         '1bda9e93-5595-4ed8-86d7-5a5d9160b257',
# ...

# %%
py.plot(fig, filename = 'P_E Ratio of airlines and its competitors', auto_open=True)
# Out:
# 'https://plotly.com/~popkdodge/20/'

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=DAL_Q['Debt to Equity Ratio'],
                name='DAL',marker_color='rgb(0,50,104)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=LUV_Q['Debt to Equity Ratio'],
                name='LUV',marker_color='rgb(242,177,18)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=AAL_Q['Debt to Equity Ratio'],
                name='AAL',marker_color='rgb(179,192,199)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=UAL_Q['Debt to Equity Ratio'],
                name='UAL',marker_color='rgb(2,180,232)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=DAL_Q['Debt to Equity Ratio'],
                    mode='lines+markers',
                    name='DAL',marker_color='rgb(0,50,104)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=LUV_Q['Debt to Equity Ratio'],
                    mode='lines+markers',
                    name='LUV',marker_color='rgb(242,177,18)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=AAL_Q['Debt to Equity Ratio'],
                    mode='lines+markers',
                    name='AAL',marker_color='rgb(179,192,199)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=UAL_Q['Debt to Equity Ratio'],
                    mode='lines+markers',
                    name='UAL',marker_color='rgb(2,180,232)'))




fig.update_layout(
    title={
        'text': "Debt to Equity Ratio of DAL and its Competitors",
        'font': dict(
        family="Courier New, monospace",
        size=29,
        color="#212121")}

            
    ,xaxis_title='Quarterlies'
    ,yaxis_title=''
        )


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="22967c33-94fe-4046-81fd-631e0c167ec3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("22967c33-94fe-4046-81fd-631e0c167ec3")) {
#                     Plotly.newPlot(
#                         '22967c33-94fe-4046-81fd-631e0c167ec3',
# ...

# %%
py.plot(fig, filename = 'Debt to Equity Airlines', auto_open=True)
# Out:
# 'https://plotly.com/~popkdodge/22/'

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=DAL_Q['Free Cash Flow'],
                name='DAL',marker_color='rgb(0,50,104)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=LUV_Q['Free Cash Flow'],
                name='LUV',marker_color='rgb(242,177,18)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=AAL_Q['Free Cash Flow'],
                name='AAL',marker_color='rgb(179,192,199)'))
fig.add_trace(go.Bar(x=DAL_Q['Time'], y=UAL_Q['Free Cash Flow'],
                name='UAL',marker_color='rgb(2,180,232)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=DAL_Q['Free Cash Flow'],
                    mode='lines+markers',
                    name='DAL',marker_color='rgb(0,50,104)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=LUV_Q['Free Cash Flow'],
                    mode='lines+markers',
                    name='LUV',marker_color='rgb(242,177,18)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=AAL_Q['Free Cash Flow'],
                    mode='lines+markers',
                    name='AAL',marker_color='rgb(179,192,199)'))
fig.add_trace(go.Scatter(x=DAL_Q['Time'], y=UAL_Q['Free Cash Flow'],
                    mode='lines+markers',
                    name='UAL',marker_color='rgb(2,180,232)'))



fig.update_layout(
    title={
        'text': "Free Cash Flow of DAL and its Competitors",
        'font': dict(
        family="Courier New, monospace",
        size=29,
        color="#212121")}

            
    ,xaxis_title='Quarterlies'
    ,yaxis_title='Dollars($)'
        )



fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e0cb8dc8-9391-4e70-9462-ee3f30b39d1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e0cb8dc8-9391-4e70-9462-ee3f30b39d1c")) {
#                     Plotly.newPlot(
#                         'e0cb8dc8-9391-4e70-9462-ee3f30b39d1c',
# ...

# %%
py.plot(fig, filename = 'FCF Airlines', auto_open=True)
# Out:
# 'https://plotly.com/~popkdodge/25/'

# %%
'17.5','16.7','14.8','6.4','5.5','4.3','3.6','2.9','1.6','9.6'
